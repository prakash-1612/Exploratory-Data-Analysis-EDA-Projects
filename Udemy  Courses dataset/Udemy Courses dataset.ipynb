# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\prakash\Downloads\udemy_courses.csv")
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %% [markdown]
# ### 1.waht are all different subject for which udemy is offering courses?

# %%
#drop subject unique()

# %%
df.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# ### 2.which subject has the maximum number of courses.

# %%
#data.subject.value_counts()

# %%
 df.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
df.drop(["url"],axis=1,inplace=True)
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0       1070968                 Ultimate Investment Banking Course     True
# 1       1113822  Complete GST Course & Certification - Grow You...     True
# 2       1006314  Financial Modeling for Business Analysts and C...     True
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4       1011058       How To Maximize Your Profits Trading Options     True
# ...         ...                                                ...      ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...     True
# 3674    1088178  How To Design A WordPress Website With No Codi...     True
# 3675     635248                      Learn and Build using Polymer     True
# 3676     905096  CSS Animations: Create Amazing Effects on Your...     True
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...     True
#
# ...

# %%
df.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %% [markdown]
# ### 3.Show all the courses which are Free of cost.

# %%
#data[data.is_paid==false]

# %%
df.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0    1070968                 Ultimate Investment Banking Course     True
# 1    1113822  Complete GST Course & Certification - Grow You...     True
#
#    price  num_subscribers  num_reviews  num_lectures       level  \
# 0    200             2147           23            51  All Levels
# 1     75             2792          923           274  All Levels
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance

# %%
df[df.is_paid == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 95      1148774                    Options Trading 101: The Basics    False
# 103      133536               Stock Market Investing for Beginners    False
# 106      265960                      Fundamentals of Forex Trading    False
# 108      923616  Website Investing 101 - Buying & Selling Onlin...    False
# 112      191854                           Stock Market Foundations    False
# ...         ...                                                ...      ...
# 3638     155640            Building a Search Engine in PHP & MySQL    False
# 3643     366720  CSS Image filters - The modern web images colo...    False
# 3651    1079078                             Drupal 8 Site Building    False
# 3665      21386               Beginner Photoshop to HTML5 and CSS3    False
# 3668     270976                             A how to guide in HTML    False
#
# ...

# %% [markdown]
# ### 4.show all the courses which are paid

# %%
#data[data.is_paid == True]

# %%
df[df.is_paid == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0       1070968                 Ultimate Investment Banking Course     True
# 1       1113822  Complete GST Course & Certification - Grow You...     True
# 2       1006314  Financial Modeling for Business Analysts and C...     True
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4       1011058       How To Maximize Your Profits Trading Options     True
# ...         ...                                                ...      ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...     True
# 3674    1088178  How To Design A WordPress Website With No Codi...     True
# 3675     635248                      Learn and Build using Polymer     True
# 3676     905096  CSS Animations: Create Amazing Effects on Your...     True
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...     True
#
# ...

# %% [markdown]
# ### 5.Which Top selling courses?

# %%
#df.sort_values['num_subcribers',ascending = False)

# %%
df.sort_values('num_subscribers',ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2827      41295               Learn HTML5 Programming From Scratch    False
# 3032      59014                     Coding for Entrepreneurs Basic    False
# 3230     625204                         The Web Developer Bootcamp     True
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3232     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 1569     726314       Create Beautiful Image Maps for Your Website     True
# 1473     185526                             MicroStation - Células     True
# 1472     181268               Photoshop: Creando elemental de aire     True
# 1471     188584                        Letras en Adobe Illustrator     True
# 2405    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...     True
#
# ...

# %% [markdown]
# ### 6.Which are Least selling courses?

# %%
#df.sort_values('num_subscribers')

# %%
df.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  is_paid  \
# 885     1032648                               beginning accounting     True
# 456     1247992  Introduction to Project Management for Finance...     True
# 457     1251582              Best Practices in Corporate Budgeting     True
# 458     1258666                Financial Statement Auditing Cycles     True
# 459     1168172       Case studies on credit appraisal for bankers     True
# ...         ...                                                ...      ...
# 3232     764164              The Complete Web Developer Course 2.0     True
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3230     625204                         The Web Developer Bootcamp     True
# 3032      59014                     Coding for Entrepreneurs Basic    False
# 2827      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %% [markdown]
# ### 7.Show all courses of Graphic design where the price is below 100?

# %%
#df[(df.subject == 'Graphic Design') & (df.price < '100')]

# %%
df.head(1)
# Out:
#    course_id                        course_title  is_paid  price  \
# 0    1070968  Ultimate Investment Banking Course     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df[(df.subject == 'Graphic Design') & (df.price < 100) ]
# Out:
#       course_id                                       course_title  is_paid  \
# 1196    1197206                         Illustrator CC MasterClass     True
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...     True
# 1202      28556              Discover How to Draw and paint Comics     True
# 1203     317278  Typographic Logos: Typography and Lettering fo...     True
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...     True
# ...         ...                                                ...      ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide     True
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop     True
# 1795     496430  Infographic Design: How To Create Your Own Inf...     True
# 1796     793246           Autodesk Inventor 2016 : Complete Guide      True
# 1797     547190               Amazing Graphic Design for Beginners     True
#
# ...

# %%
 df[(df.subject == 'Graphic Design') & (df.price ==  100) ]
# Out:
#       course_id                                       course_title  is_paid  \
# 1248    1160004                 Design a logo for FREE in Inkscape     True
# 1288     927186        Learn Blender 3D  - The introduction course     True
# 1338     638040  Adobe Photoshop Essentials: Master Adobe Photo...     True
# 1347    1246168  Illustrator para criação de peças gráficas, De...     True
# 1376     654038              How To Sell Your Art Online With ETSY     True
# 1380    1243016        Photoshop - Tratamento de pele profissional     True
# 1381    1266468  Indesign - Para quem quer trabalhar com Design...     True
# 1417     978462              Blender Modelling Series - Volume Two     True
# 1452    1027080              Logo Portfolio in 1 Hour in Wordpress     True
# 1489     482924  Mastering Retouching and Restoration (15 proje...     True
# 1507    1161864  Diseño impreso - Preimpresión para offset en I...     True
# ...

# %% [markdown]
# ### 8.List out all the courses that are related with 'Python'.

# %%
#df[df.courses_title.contains9('Python') ]

# %%
df.head(1)
# Out:
#    course_id                        course_title  is_paid  price  \
# 0    1070968  Ultimate Investment Banking Course     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df[df.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News     True
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!     True
# 41      1035472  Python for Finance: Investment Fundamentals & ...     True
# 147     1070886         Python Algo Trading: FX Trading with Oanda     True
# 334      815482               Stock Technical Analysis with Python     True
# 536      529828                     Python for Trading & Investing     True
# 762     1088656          Quantitative Trading Analysis with Python     True
# 863      902888          Investment Portfolio Analysis with Python     True
# 1682     546848  Learn to code in Python and learn Adobe Photos...     True
# 2497      16646                        Web Programming with Python     True
# 2528     391546        Learn Python and Django: Payment Processing     True
# ...

# %%
len(df[df.course_title.str.contains('Python')])
# Out:
# 29

# %% [markdown]
# ### 9.What are courses that published in year 2015?

# %%
#df.dtypes
#df['published_timestamp'] = pd.to_datetime(df.published_timestamp)
#df.dtypes
#df['year'] = df['published_timestamp'].dt.year
#df[df.year == 2015]

# %%
df.head(1)
# Out:
#    course_id                        course_title  is_paid  price  \
# 0    1070968  Ultimate Investment Banking Course     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df['published_timestamp'] = pd.to_datetime(df.published_timestamp)

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df.head(1)
# Out:
#    course_id                        course_title  is_paid  price  \
# 0    1070968  Ultimate Investment Banking Course     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
#df['year'] = df['published_timestamp'].dt.year

df['year'] = df['published_timestamp'].dt.year
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0       1070968                 Ultimate Investment Banking Course     True
# 1       1113822  Complete GST Course & Certification - Grow You...     True
# 2       1006314  Financial Modeling for Business Analysts and C...     True
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4       1011058       How To Maximize Your Profits Trading Options     True
# ...         ...                                                ...      ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...     True
# 3674    1088178  How To Design A WordPress Website With No Codi...     True
# 3675     635248                      Learn and Build using Polymer     True
# 3676     905096  CSS Animations: Create Amazing Effects on Your...     True
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...     True
#
# ...

# %%
df[df.year == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...     True
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...     True
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...     True
# 15       504036  Short Selling: Learn To Sell Stocks Before The...     True
# 17       564966  The Complete Chart Pattern Trading Course: A P...     True
# ...         ...                                                ...      ...
# 3659     577796  Simple Javascript: Learn by Doing, Beginners W...     True
# 3667     523216  The Fastest Way to Create a Website Using Godaddy     True
# 3669     679992                  Building Better APIs with GraphQL     True
# 3671     667122  Build A Stock Downloader With Visual Studio 20...     True
# 3675     635248                      Learn and Build using Polymer     True
#
# ...

# %% [markdown]
# ### 10.What are the Max. Number of Subscribers for each level of courses?

# %%
#df.groupby('level')['num_subscribers'].max()
#df.groupby('level').max()

# %%
df.head(1)
# Out:
#    course_id                        course_title  is_paid  price  \
# 0    1070968  Ultimate Investment Banking Course     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
df.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid  price  num_subscribers  num_reviews  \
# level
# All Levels             True    200           268923        27445
# Beginner Level         True    200           161029         5924
# Expert Level           True    200             5172          249
# Intermediate Level     True    200            29167         3326
#
#                     num_lectures  content_duration       published_timestamp  \
# level
# ...
